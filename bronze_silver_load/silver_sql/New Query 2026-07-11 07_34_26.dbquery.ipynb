-- %%
SELECT * FROM clintrail_dev.clintrail_bronze.cm;
SELECT count(*) FROM clintrail_dev.clintrail_silver.cm;
--TRUNCATE TABLE clintrail_dev.clintrail_silver.cm


SELECT count(*) FROM clintrail_dev.clintrail_silver.eg;
SELECT count(*) FROM clintrail_dev.clintrail_silver.ta;
SELECT count(*) FROM clintrail_dev.clintrail_silver.vs;
